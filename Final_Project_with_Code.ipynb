# %% [markdown]
# ![Screenshot%202024-06-23%20001708.png](attachment:Screenshot%202024-06-23%20001708.png)

# %% [markdown]
# ### List of Tables

# %% [markdown]
# ### List of figures

# %% [markdown]
# ### Problem Statement/Objetive
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape. By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience. The analysis will provide valuable insights and recommendations for stakeholders in the education sector.

# %% [markdown]
# ### Data Description
#
# * Names: Names of various university and colleges
# * Apps: Number of applications received
# * Accept: Number of applications accepted
# * Enroll: Number of new students enrolled
# * Top10perc: Percentage of new students from top 10% of Higher Secondary class
# * Top25perc: Percentage of new students from top 25% of Higher Secondary class
# * F.Undergrad: Number of full-time undergraduate students
# * P.Undergrad: Number of part-time undergraduate students
# * Outstate: Number of students for whom the particular college or university is Out-of-state tuition
# * Room.Board: Cost of Room and board
# * Books: Estimated book costs for a student
# * Personal: Estimated personal spending for a student
# * PhD: Percentage of faculties with Ph.D.’s
# * Terminal: Percentage of faculties with terminal degree
# * S.F.Ratio: Student/faculty ratio
# * perc.alumni: Percentage of alumni who donate
# * Expend: The Instructional expenditure per student
# * Grad.Rate: Graduation rate

# %% [markdown]
# ### Import the necessary libraries

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the dataset

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\shoeb\\Downloads\\All Projects\\1-Education_Post_12th_Standard_New.csv')

# %% [markdown]
# ## Basic Data Exploration

# %% [markdown]
# #### 1-	Display the top 5 rows.

# %%
df.head()
# Out:
#                           Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 0  Abilene Christian University  1660.0    1232   721.0       23.0         52
# 1            Adelphi University  2186.0    1924   512.0       16.0         29
# 2                Adrian College  1428.0    1097   336.0       22.0         50
# 3           Agnes Scott College   417.0     349     NaN       60.0         89
# 4     Alaska Pacific University   193.0     146    55.0       16.0         44
#
#    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 0         2885          537      7440        3300    450    2200.0   70
# 1         2683         1227     12280        6450    750    1500.0   29
# 2         1036           99     11250        3750    400    1165.0   53
# 3          510           63     12960        5450    450     875.0   92
# 4          249          869      7560        4120    800    1500.0   76
#
#    Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# ...

# %% [markdown]
# #### 2-	Display the last 5 rows

# %%
df.tail()
# Out:
#                               Names     Apps  Accept  Enroll  Top10perc  \
# 772         Worcester State College   2197.0    1515   543.0        4.0
# 773               Xavier University   1959.0    1805   695.0       24.0
# 774  Xavier University of Louisiana   2097.0    1915   695.0       34.0
# 775                 Yale University  10705.0    2453  1317.0       95.0
# 776    York College of Pennsylvania   2989.0    1855   691.0       28.0
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# ...

# %% [markdown]
# #### 3-	Check the shape of dataset.

# %%
df.shape
# Out:
# (777, 18)

# %% [markdown]
# #### 4-	Check the datatypes of each feature.

# %%
df.dtypes
# Out:
# Names           object
# Apps           float64
# Accept           int64
# Enroll         float64
# Top10perc      float64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal       float64
# PhD              int64
# Terminal         int64
# S.F.Ratio       object
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %% [markdown]
# #### 5-	Check the Statistical summary

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    775.000000    777.000000   775.000000  773.000000  777.000000
# mean    3007.592258   2018.804376   780.961290   27.620957   55.796654
# std     3873.414660   2451.113971   930.077779   17.645470   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      778.000000    604.000000   242.500000   15.000000   41.000000
# 50%     1561.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3635.000000   2424.000000   902.500000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   547.875161
# std     4850.420531   1522.431887   4023.016484  1096.696416   167.426237
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        777 non-null    object
#  1   Apps         775 non-null    float64
#  2   Accept       777 non-null    int64
#  3   Enroll       775 non-null    float64
#  4   Top10perc    773 non-null    float64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     774 non-null    float64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    object
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# ...

# %%
# conversion S.F.Ratio into float64

df["S.F.Ratio"] = df["S.F.Ratio"].astype(float)

# # df['S.F.Ratio'] = df['S.F.Ratio'].astype(str).astype(int)
# df['S.F.Ratio'] = df['S.F.Ratio'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Names           777 non-null    object
#  1   Apps            777 non-null    float64
#  2   Accept          777 non-null    int64
#  3   Enroll          777 non-null    float64
#  4   Top10perc       777 non-null    float64
#  5   Top25perc       777 non-null    int64
#  6   F.Undergrad     777 non-null    int64
#  7   P.Undergrad     777 non-null    int64
#  8   Outstate        777 non-null    int64
#  9   Room.Board      777 non-null    int64
#  10  Books           777 non-null    int64
#  11  Personal        777 non-null    float64
#  12  PhD             777 non-null    int64
#  13  Terminal        777 non-null    int64
#  14  S.F.Ratio       777 non-null    float64
#  15  perc.alumni     777 non-null    int64
#  16  Expend          777 non-null    int64
# ...

# %%
# check minimum value

df.min()
# Out:
# Names          Abilene Christian University
# Apps                                   81.0
# Accept                                   72
# Enroll                                 35.0
# Top10perc                               1.0
# Top25perc                                 9
# F.Undergrad                             139
# P.Undergrad                               1
# Outstate                               2340
# Room.Board                             1780
# Books                                     0
# Personal                               50.0
# PhD                                       8
# Terminal                                 24
# S.F.Ratio                                10
# perc.alumni                               0
# Expend                                 3186
# Grad.Rate                                10
# dtype: object

# %%
# check maximum value

df.max()
# Out:
# Names          York College of Pennsylvania
# Apps                                48094.0
# Accept                                26330
# Enroll                               6392.0
# Top10perc                              96.0
# Top25perc                               100
# F.Undergrad                           31643
# P.Undergrad                           21836
# Outstate                              21700
# Room.Board                             8124
# Books                                  2340
# Personal                           205500.0
# PhD                                     103
# Terminal                                100
# S.F.Ratio                                 ?
# perc.alumni                              64
# Expend                                56233
# Grad.Rate                               118
# dtype: object

# %%
# check for percentage wise missing value in columns

df.isnull().sum()/len(df)*100
# Out:
# Names          0.000000
# Apps           0.257400
# Accept         0.000000
# Enroll         0.257400
# Top10perc      0.514801
# Top25perc      0.000000
# F.Undergrad    0.000000
# P.Undergrad    0.000000
# Outstate       0.000000
# Room.Board     0.000000
# Books          0.000000
# Personal       0.386100
# PhD            0.000000
# Terminal       0.000000
# S.F.Ratio      0.000000
# perc.alumni    0.000000
# Expend         0.000000
# Grad.Rate      0.000000
# Enroll_Rate    0.000000
# dtype: float64

# %% [markdown]
# #### 6-	Check the null values

# %%
df.isnull().sum()
# Out:
# Names          0
# Apps           2
# Accept         0
# Enroll         2
# Top10perc      4
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       3
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# Enroll_Rate    0
# dtype: int64

# %% [markdown]
# #### 7-	Check the duplicate values

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# Length: 777, dtype: bool

# %%
# checking the how many total duplicated values present

df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum().sum()
# Out:
# 11

# %%
df['Enroll'].fillna(125)
# Out:
# 0       721.0
# 1       512.0
# 2       336.0
# 3       125.0
# 4        55.0
#         ...
# 772     543.0
# 773     695.0
# 774     695.0
# 775    1317.0
# 776     691.0
# Name: Enroll, Length: 777, dtype: float64

# %%
type(df.head())
# Out:
# pandas.core.frame.DataFrame

# %%
# data.to_csv('saved')

# %%
df.sample(3)
# Out:
#                    Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 35         Barat College   261.0     192   111.0       15.0         36
# 301  Lake Forest College   979.0     638   271.0       31.0         70
# 579    Taylor University  1769.0    1092   437.0       41.0         80
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 35           453          266      9690        4300    500     500.0   57
# 301          968           20     16880        3970    920    1320.0   91
# 579         1757           81     10965        4000    450    1250.0   60
#
#      Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 35         77       9.7           35    9337         71
# 301        94      10.7           19   15687         77
# 579        61      14.2           32    8294         98

# %%
# min function
df['Apps'].min()
# Out:
# 81.0

# %%
#mx function()
df['Apps'].max()
# Out:
# 48094.0

# %% [markdown]
# ### Observation

# %%
# the minimum value of books for some

# %%
for i in ["Enroll","Outstate","S.F.Ratio","Grad.Rate"]:
    plt.figure(figsize=(10,3))
    sns.boxplot(data = df.x=i)
    plt.show
# Out:
#   Cell In[55], line 3
#     sns.boxplot(data = df.x=i)
#                            ^
# SyntaxError: invalid syntax

# %%
# getting rows with S.F.Ratio as "?"

df[df["S.F.Ratio"] == "?"]
# Out:
#                      Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 1       Adelphi University  2186.0    1924   512.0       16.0         29
# 81     Campbell University  2087.0    1339     NaN       20.0         54
# 241  Gwynedd Mercy College   380.0     237   104.0       30.0         56
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 1           2683         1227     12280        6450    750    1500.0   29
# 81          3191         1204      7550        2790    600     500.0   77
# 241          716         1108     11000        5550    500     500.0   36
#
#      Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate  Enroll_Rate
# 1          30         ?           16   10527         56         1924
# 81         77         ?           34    3739         63         1339
# 241        41         ?           22    7483         96          237

# %%
# Replacing  "?" with null values

df["S.F.Ratio"] = df["S.F.Ratio"].replace('?',np.nan)

# %%
df[df["S.F.Ratio"] == "?"]
# Out:
# Empty DataFrame
# Columns: [Names, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate, Enroll_Rate]
# Index: []

# %%
df["S.F.Ratio"].value_counts()
# Out:
# S.F.Ratio
# 12.1    15
# 11.3    14
# 12.5    13
# 11.1    13
# 13.3    13
#         ..
# 28.8     1
# 20.4     1
# 22.1     1
# 27.2     1
# 8.5      1
# Name: count, Length: 172, dtype: int64

# %% [markdown]
# ### Then we use distplot or density plot to check the normality. Normality means whether the data is normally distributed or not

# %%
# check the distribution of data

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Apps'])

plt.subplot(1,2,2)
sns.distplot(df['Enroll'])

plt.show()
# Out:
# C:\Users\shoeb\AppData\Local\Temp\ipykernel_15904\7396647.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Apps'])
# C:\Users\shoeb\AppData\Local\Temp\ipykernel_15904\7396647.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Enroll'])

# %% [markdown]
# #### 9-	Check the outliers and their authenticity

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df,orient='h')
plt.show()

# %%
for i in ["apps","Accept","Personal","S.F.Ratio"]:
    plt.figure(figsize=(10,3))
    sns.boxplot(data=df,orient='i')
    plt.show

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.boxplot(data = df,x = i)
        plt.show()

# %%
df.isnull().sum()
# Out:
# Names          0
# Apps           2
# Accept         0
# Enroll         2
# Top10perc      4
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       3
# PhD            0
# Terminal       0
# S.F.Ratio      3
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# Enroll_Rate    0
# dtype: int64

# %%
df.dtypes
# Out:
# Names           object
# Apps           float64
# Accept           int64
# Enroll         float64
# Top10perc      float64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal       float64
# PhD              int64
# Terminal         int64
# S.F.Ratio       object
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# Enroll_Rate      int64
# dtype: object

# %% [markdown]
# #### First check for the outliers

# %%
for i in ["Apps","Enroll","Top10perc","Personal"]:
    plt.figure(figsize =(10,3))
    sns.boxplot(data = df,x=i)
    plt.show()

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
lr,ur = remove_outlier(df["Apps"])

# %%
df[df["Apps"]>ur]
# Out:
#                                     Names     Apps  Accept  Enroll  Top10perc  \
# 23   Arizona State University Main campus  12809.0   10308  3761.0       24.0
# 59                      Boston University  20192.0   13007  3810.0       45.0
# 61         Bowling Green State University   9251.0    7333  3076.0       14.0
# 70                       Brown University  12586.0    3239  1462.0       87.0
# 87             Carnegie Mellon University   8728.0    5201  1191.0       60.0
# ..                                    ...      ...     ...     ...        ...
# 694              University of Washington  12749.0    7025  3343.0       40.0
# 700    University of Wisconsin at Madison  14901.0   10932  4631.0       36.0
# 713                         Virginia Tech  15712.0   11719  4277.0       29.0
# 743           Western Michigan University   9167.0    7191  2738.0       24.0
# 775                       Yale University  10705.0    2453  1317.0       95.0
#
# ...

# %%
df[df["Apps"]<lr]
# Out:
# Empty DataFrame
# Columns: [Names, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate, Enroll_Rate]
# Index: []

# %% [markdown]
# #### Outliers are present so Replacing Null Values in Numerical columns usig  median

# %%
median1 = df["Apps"].median()
median2 = df["Enroll"].median()
median3 = df["Top10perc"].median()
median4 = df["Personal"].median()
median5 = df["S.F.Ratio"].median()


df["Apps"].replace(np.nan,median1,inplace = True)
df["Enroll"].replace(np.nan,median2,inplace = True)
df["Top10perc"].replace(np.nan,median3,inplace = True)
df["Personal"].replace(np.nan,median4,inplace = True)
df["S.F.Ratio"].replace(np.nan,median5,inplace = True)

# %%
# check for missing value in any culumns 

df.isnull().sum()
# Out:
# Names          0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# Enroll_Rate    0
# dtype: int64

# %% [markdown]
# ### outliers treatment

# %%
for i in ["Apps","Enroll","Top10perc","Personal"]:
    plt.figure(figsize=(10,3))
    df.boxplot(column = i)
    plt.show()

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
#Replacing outliers with lower and upper ranges

lr_Apps,ur_Apps=remove_outlier(df["Apps"])
df["Apps"]=np.where(df["Apps"]>ur_Apps,ur_Apps,df["Apps"])
df["Apps"]=np.where(df["Apps"]<lr_Apps,lr_Apps,df["Apps"])


lr_Enroll,ur_Enroll=remove_outlier(df["Enroll"])
df["Enroll"]=np.where(df["Enroll"]>ur_Enroll,ur_Enroll,df["Enroll"])
df["Enroll"]=np.where(df["Enroll"]<lr_Enroll,lr_Enroll,df["Enroll"])                             

lr_Top10perc,ur_Top10perc = remove_outlier(df["Top10perc"]) 
df["Top10perc"]=np.where(df["Top10perc"]>ur_Top10perc,ur_Top10perc,df["Top10perc"])
df["Top10perc"]=np.where(df["Top10perc"]<lr_Top10perc,lr_Top10perc,df["Top10perc"]) 

                               
lr_Personal,ur_Personal= remove_outlier(df["Personal"])
df["Personal"]=np.where(df["Personal"]>ur_Personal,ur_Personal,df["Personal"])
df["Personal"]=np.where(df["Personal"]<lr_Personal,lr_Personal,df["Personal"])

# %% [markdown]
# #### after outliers remove

# %%
for i in ["Apps","Enroll","Top10perc","Personal"]:
    plt.figure(figsize=(10,3))
    df.boxplot(column = i)
    plt.show()

# %% [markdown]
# #### 10-	Do the necessary data cleaning steps like dropping duplicates, unnecessary columns, null value imputation, outliers treatment etc.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Names          0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# Enroll_Rate    0
# dtype: int64

# %%
df[df.isnull().sum(axis = 1)>0]
# Out:
# Empty DataFrame
# Columns: [Names, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate, Enroll_Rate]
# Index: []

# %%
df["Enroll"].mean()
# Out:
# 660.3314028314028

# %% [markdown]
# ## 1.Application and Enrollment Analysis

# %% [markdown]
# #### •	What is the average number of applications received by colleges?

# %%
avg_num_appli = df["Apps"].mean()
print(f"The Average number of application recevied by colleges:{avg_num_appli:.2f}")
# avg_num_applica 

plt.figure(figsize=(10,6))
sns.histplot(df["Apps"],kde = True,bins = 20)
plt.axvline(avg_num_appli,color = "r",linestyle = "--",label = f"avg_num_appli,{avg_num_appli:.2f}%")
plt.title("The Average number of application recevied by colleges")
plt.xlabel("avg number of application")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average number of application recevied by colleges:2573.04

# %% [markdown]
# #### •	What percentage of applications are accepted on average across all colleges?

# %%
# (df["Apps"].sum()/df["Apps"].sum())*100

# average_acceptance_rate = (df['Accept'] / df['Apps']).mean() * 100

df['AcceptanceRate'] = (df['Accept'] / df['Apps']) * 100

# print(f"Average percentage of applications accepted: {average_acceptance_rate:.2f}%")

plt.figure(figsize=(12, 6))
sns.histplot(df['AcceptanceRate'], kde=True, bins=20)
plt.axvline(average_acceptance_rate, color='r', linestyle='--', label=f'Average Acceptance Rate: {average_acceptance_rate:.2f}%')
plt.title('Distribution of Acceptance Rates Across All Colleges')
plt.xlabel('Acceptance Rate (%)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# #### •	Which college has the highest number of applications received?

# %%
highest_apps_college = df.loc[df['Apps'].idxmax(), 'Names']
print(f"College with the highest number of applications received: {highest_apps_college}")

# college_max_apps = df.loc[df['Apps'].idxmax()]
# print(f"The college with the highest number of applications received is {college_max_apps['Names']} with {college_max_apps['Apps']} applications.")

# df.value_counts
# Out:
# College with the highest number of applications received: Rutgers at New Brunswick

# %% [markdown]
# #### •	What is the average enrollment rate (number of students enrolled divided by number of applications accepted)?

# %%
average_enrollment_rate = (df['Enroll'] / df['Accept']).mean() * 100
print(f"Average enrollment rate: {average_enrollment_rate:.2f}%")
# Out:
# Average enrollment rate: 41.19%

# %% [markdown]
# #### ​Which college has the highest number of applications received?

# %%
df.loc[df["Apps"].idxmax(),"Names"]
# df.value_counts
# Out:
# 'Rutgers at New Brunswick'

# %% [markdown]
# ## 2. Academic Excellence

# %% [markdown]
# ####  •	What is the average percentage of new students from the top 10% of their higher secondary class across all colleges?

# %%
average_top10perc = df["Top10perc"].mean()

plt.figure(figsize=(6, 4))
plt.bar(['Average Top 10%'], [average_top10perc], color='blue')
plt.ylabel('Percentage')
plt.title('Average Percentage of New Students from Top 10% of Higher Secondary Class')
plt.ylim(0, 100)  # Assuming the percentage scale is from 0 to 100

# Annotate the bar with the average value
plt.text(0, average_top10perc + 1, f'{average_top10perc:.2f}%', ha='center', va='bottom')

# Display the plot
plt.show()

# %% [markdown]
# #### • What is the average percentage of new students from the top 25% of their higher secondary class?

# %%
mean1 = df["Top25perc"].mean()

plt.axvline(mean1, color='orange', linestyle='--')

# %% [markdown]
# ####  Is there a correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class?

# %%
df["Top10perc"].corr(df["Top25perc"])
# Out:
# 0.9119061816018956

# %% [markdown]
# ## 3. Student Demographics

# %% [markdown]
# #### • What is the average number of full-time undergraduate students per college?

# %%
avg_num_Fulltime_ug = df["F.Undergrad"].mean()
print(f"The Average number of full time undergraduate student per college:{avg_num_Fulltime_ug:.2f}")
plt.figure(figsize=(10,6))
sns.histplot(df["F.Undergrad"],kde = True,color = "red",edgecolor = "b",bins = 20)
plt.axvline(avg_num_ug,color = "b",linestyle = "dotted",label = f"avg_num_Fulltime_ug,{avg_num_Fulltime_ug:.2f}%")
plt.title("The Average number of full time undergraduate student per college")
plt.xlabel("Avg number of fulltime UG Student (%)")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average number of full time undergraduate student per college:3699.91

# %% [markdown]
# #### What is the average number of part-time undergraduate students per college?

# %%
avg_num_PartTime_ug = df["P.Undergrad"].mean()
print(f"The Average number of full time undergraduate student per college:{avg_num_PartTime_ug:.2f}")

plt.figure(figsize=(10,6))
sns.histplot(df["P.Undergrad"],kde = True,color = "b",edgecolor = "r",bins = 20)
plt.axvline(avg_num_ug,color = "b",linestyle = "dotted",label = f"avg_num_PartTime_ug,{avg_num_PartTime_ug:.2f}%")
plt.title("The Average number of part-time undergraduate student per college")
plt.xlabel("Avg number of fulltime UG Student")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average number of full time undergraduate student per college:855.30

# %% [markdown]
# #### • Which college has the highest number of out-of-state students?

# %%
highest_outstate_college = df.loc[df["Outstate"].idxmax(),"Names"]
highest_outstate_college
plt.figure(figsize=(15, 6))
sns.barplot(x='Names', y='Outstate', data=df.sort_values(by='Outstate', ascending=False).head(10))
plt.axhline(highest_outstate_college['Outstate'], color='r', linestyle='--', label=f'Highest Out-of-State Students: {highest_outstate_college["Outstate"]}')
plt.title('Top 10 Colleges with Highest Number of Out-of-State Students')
plt.xlabel('College Names')
plt.ylabel('Number of Out-of-State Students')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[458], line 5
#       3 plt.figure(figsize=(15, 6))
#       4 sns.barplot(x='Names', y='Outstate', data=df.sort_values(by='Outstate', ascending=False).head(10))
# ----> 5 plt.axhline(highest_outstate_college['Outstate'], color='r', linestyle='--', label=f'Highest Out-of-State Students: {highest_outstate_college["Outstate"]}')
#       6 plt.title('Top 10 Colleges with Highest Number of Out-of-State Students')
#       7 plt.xlabel('College Names')
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# ## 4. Cost and Spending

# %% [markdown]
# #### • What is the average cost of room and board across all colleges?

# %%
avg_room_board = df["Room.Board"].mean()
# avg_room_board

print(f"The Average cost of room and board across all colleges : {avg_room_board:.2f}")

plt.figure(figsize = (10,6))
sns.histplot(df["Room.Board"],kde = True,color='blue',edgecolor='b',bins = 20)
plt.axvline(avg_room_board,color = "r",linestyle = "--",label = f"avg_room_board : {avg_room_board:.2f}%")
plt.title("The Average cost of room board across all colleges")
plt.xlabel("avg_room_board")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average cost of room and board across all colleges : 4357.53

# %% [markdown]
# #### • What is the average estimated book cost for a student?

# %%
avg_book_cost = df["Books"].mean()

print(f"The Average average estimated book cost for a student : {avg_book_cost:.2f}")

plt.figure(figsize = (10,6))
sns.histplot(df["Books"],kde = True,color='blue',edgecolor='b',bins = 20)
plt.axvline(avg_book_cost,color = "r",linestyle = "--",label = f"avg_room_board : {avg_book_cost:.2f}%")
plt.title("The Average cost of room board across all colleges")
plt.xlabel("avg_room_board")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average average estimated book cost for a student : 547.88

# %% [markdown]
# #### • What is the average estimated personal spending for a student?

# %%
df["Personal"].mean()
# Out:
# 1320.065637065637

# %% [markdown]
# #### • How does the instructional expenditure per student vary across colleges?

# %%
print(df['Expend'].describe())

# Visualize the distribution of 'Expend' using a histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Expend'], bins=20, kde=True, color='blue')
plt.title('Distribution of Instructional Expenditure per Student')
plt.xlabel('Instructional Expenditure')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# count      777.000000
# mean      9660.171171
# std       5221.768440
# min       3186.000000
# 25%       6751.000000
# 50%       8377.000000
# 75%      10830.000000
# max      56233.000000
# Name: Expend, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Names', y='Expend', data=df)
plt.xticks(rotation=90)
plt.title('Instructional Expenditure per Student Across Colleges')
plt.xlabel('College Names')
plt.ylabel('Instructional Expenditure')
plt.show()

# %%
top_n = 10  # Example: Top 10 colleges by expenditure
top_colleges = df.nlargest(top_n, 'Expend')

plt.figure(figsize=(12, 6))
sns.barplot(x='Names', y='Expend', data=top_colleges)
plt.xticks(rotation=45)
plt.title(f'Top {top_n} Colleges by Instructional Expenditure per Student')
plt.xlabel('College Names')
plt.ylabel('Instructional Expenditure')
plt.show()

# %% [markdown]
# ## 5. Faculty Qualifications

# %% [markdown]
# #### • What is the average percentage of faculties with Ph.D.s across all colleges?

# %%
avg_phd_faculty = df["PhD"].mean()
# avg_phd_faculty 
print(f"The Average percentage of Faculty with PhD across all colleges is : {avg_phd_faculty:.2f}%")
plt.figure(figsize=(10,6))
sns.histplot(df["PhD"],kde = True,bins = 20)
plt.axvline(avg_phd_faculty,color = "r",linestyle = "--",label = f"avg_phd_faculty : {avg_phd_faculty:.2f}%")
plt.title("Average Percentage of faculty with phd across all colleges")
plt.xlabel("avg percentage_faculty with PhD %")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average percentage of Faculty with PhD across all colleges is : 72.66%

# %% [markdown]
# #### • What is the average percentage of faculties with terminal degrees?

# %%
avg_terminal = df["Terminal"].mean()

# avg_terminal 

print(f"The Average percentage of faculty with terminal degrees is : {avg_terminal:.2f}%")

plt.figure(figsize=(10,6))
sns.histplot(df["Terminal"],kde = True,bins = 20)
plt.axvline(avg_terminal,color = "r",linestyle = "--",label = f"avg_terminal,{avg_terminal:.2f}%")
plt.title("The Average percentage of faculty with terminal degrees")
plt.xlabel("avg percentage of terminal %")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average percentage of faculty with terminal degrees is : 79.70%

# %% [markdown]
# #### .Is there a correlation between the percentage of faculties with Ph.D.s and the graduation rate?

# %%
df["PhD"].corr(df["Grad.Rate"])
# Out:
# 0.3050378500234119

# %% [markdown]
# ## 6. Student-Faculty Interaction

# %% [markdown]
# #### • What is the average student/faculty ratio across all colleges?

# %%
avg_s_f_ratio_clg = df['S.F.Ratio'].mean() 

print(f"The Average student/Faculty ratio across all college is : {avg_s_f_ratio_clg:.2f}%")

plt.figure(figsize = (10,6))
sns.histplot(df["S.F.Ratio"],kde = True,bins = 20)
plt.axvline(avg_s_f_ratio_clg,color = "r",linestyle = "--",label = f"avg_s_f_ratio_clg,{avg_s_f_ratio_clg:.2f}%")
plt.title("The Average student/Faculty ratio across all college")
plt.xlabel("student/faculty ratio %")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# The Average student/Faculty ratio across all college is : 14.09%

# %% [markdown]
# #### • Which college has the lowest student/faculty ratio?

# %%
lowest_s_f_ratio_clg = df.loc[df['S.F.Ratio'].idxmin()]

# Plotting the student/faculty ratios of all colleges
plt.figure(figsize=(10, 6))
sns.barplot(x='S.F.Ratio', y='Names', data=df.sort_values(by='S.F.Ratio', ascending=True).head(10))
plt.axvline(lowest_s_f_ratio_clg['S.F.Ratio'], color='r', linestyle='--')
plt.title('Top 10 Colleges with Lowest Student/Faculty Ratio')
plt.xlabel('Student/Faculty Ratio')
plt.ylabel('College Names')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### • Is there a correlation between the student/faculty ratio and the graduation rate?

# %%
correlation_s_f_ratio_grad_rate = df["S.F.Ratio"].corr(df["Grad.Rate"])

print(f"Correlation between student/faculty ratio and graduation rate: {correlation_s_f_ratio_grad_rate:.2f}")

plt.figure(figsize=(10, 6))
sns.scatterplot(x='S.F.Ratio', y='Grad.Rate', data=df)
plt.title('Scatter Plot of Student/Faculty Ratio vs Graduation Rate')
plt.xlabel('Student/Faculty Ratio')
plt.ylabel('Graduation Rate')
plt.axhline(y=df['Grad.Rate'].mean(), color='r', linestyle='--', label='Average Graduation Rate')
plt.axvline(x=df['S.F.Ratio'].mean(), color='g', linestyle='--', label='Average Student/Faculty Ratio')
plt.legend()
plt.show()
# Out:
# Correlation between student/faculty ratio and graduation rate: -0.30

# %% [markdown]
# ## 7. Alumni Engagement

# %% [markdown]
# #### • What is the average percentage of alumni who donate across all colleges?

# %%
# df["perc.alumni"].mean()

avg_almni_donations = df['perc.alumni'].mean()
print(f"Average percentage of alumni who donate across all colleges: {avg_almni_donations:.2f}%")


plt.figure(figsize=(10,6))
sns.histplot(df["perc.alumni"],kde = True,bins = 20)
plt.axvline(avg_almni_donations,color = "r",linestyle = "--",label = f"avg_almni_donations,{avg_almni_donations:.2f}%")
plt.title("Average percentage of alumni who donate across all colleges")
plt.xlabel("percentage of alumni %")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Average percentage of alumni who donate across all colleges: 22.74%

# %% [markdown]
# #### • Is there a correlation between the percentage of alumni who donate and the graduation rate?

# %%
df["perc.alumni"].corr(df["Grad.Rate"])
# Out:
# 0.49089756228472053

# %% [markdown]
# ## 8. Graduation Rates

# %% [markdown]
# #### • What is the average graduation rate across all colleges?

# %%
average_grad_rate = df["Grad.Rate"].mean()

# plt.hist(df["Grad.Rate"].mean())

print(f"The average graduation rate across all colleges is {average_grad_rate:.2f}%")


plt.figure(figsize=(10, 6))
sns.histplot(df['Grad.Rate'], kde=True, bins=20)
plt.axvline(average_grad_rate, color='r', linestyle='--', label = f'Average Graduation Rate,{average_grad_rate:.2f}%')
plt.title('Distribution of Graduation Rates Across All Colleges')
plt.xlabel('Graduation Rate (%)')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# The average graduation rate across all colleges is 65.46%

# %% [markdown]
# #### •	Which college has the highest graduation rate?

# %%
df["Grad.Rate"].max()

highest_grad_rate_college = df.loc[df['Grad.Rate'].idxmax(),"Names"]

print(f"College with the highest graduation rate : {highest_grad_rate_college}")

plt.figure(figsize=(10, 6))
sns.barplot(x='Grad.Rate', y='Names', data=df.sort_values(by='Grad.Rate', ascending=False).head(10))
plt.axvline(highest_grad_rate_college['Grad.Rate'], color='r', linestyle='--')
plt.title('Top 10 Colleges with Highest Graduation Rate')
plt.xlabel('Graduation Rate (%)')
plt.ylabel('College Names')
plt.xticks(rotation=45)
plt.show()
# Out:
# College with the highest graduation rate : Cazenovia College
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[299], line 9
#       7 plt.figure(figsize=(10, 6))
#       8 sns.barplot(x='Grad.Rate', y='Names', data=df.sort_values(by='Grad.Rate', ascending=False).head(10))
# ----> 9 plt.axvline(highest_grad_rate_college['Grad.Rate'], color='r', linestyle='--')
#      10 plt.title('Top 10 Colleges with Highest Graduation Rate')
#      11 plt.xlabel('Graduation Rate (%)')
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# #### • Is there a correlation between the instructional expenditure per student and the graduation rate?

# %%
correlation_expenditure_gradrate = df["Expend"].corr(df["Grad.Rate"])
print("Correlation between instructional expenditure per student and graduation rate: {:.2f}".format(correlation_expenditure_gradrate))
# Out:
# Correlation between instructional expenditure per student and graduation rate: 0.39
