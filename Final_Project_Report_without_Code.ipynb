# %% [markdown]
# ![Screenshot%202024-06-23%20001708.png](attachment:Screenshot%202024-06-23%20001708.png)

# %% [markdown]
# ### Problem Statement/Objetive
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape. By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience. The analysis will provide valuable insights and recommendations for stakeholders in the education sector.

# %% [markdown]
# ### Data Description
# * Names: Names of various university and colleges
# * Apps: Number of applications received
# * Accept: Number of applications accepted
# * Enroll: Number of new students enrolled
# * Top10perc: Percentage of new students from top 10% of Higher Secondary class
# * Top25perc: Percentage of new students from top 25% of Higher Secondary class
# * F.Undergrad: Number of full-time undergraduate students
# * P.Undergrad: Number of part-time undergraduate students
# * Outstate: Number of students for whom the particular college or university is Out-of-state tuition
# * Room.Board: Cost of Room and board
# * Books: Estimated book costs for a student
# * Personal: Estimated personal spending for a student
# * PhD: Percentage of faculties with Ph.D.’s
# * Terminal: Percentage of faculties with terminal degree
# * S.F.Ratio: Student/faculty ratio
# * perc.alumni: Percentage of alumni who donate
# * Expend: The Instructional expenditure per student
# * Grad.Rate: Graduation rate

# %% [markdown]
# #### 1- Display the top 5 rows.

# %% [markdown]
# ![Screenshot%202024-06-20%20105958.png](attachment:Screenshot%202024-06-20%20105958.png)

# %% [markdown]
# #### 2- Display the last 5 rows

# %% [markdown]
# ![Screenshot%202024-06-20%20110112.png](attachment:Screenshot%202024-06-20%20110112.png)

# %% [markdown]
# #### 3- Check the shape of dataset.

# %% [markdown]
# ![Screenshot%202024-06-20%20110208.png](attachment:Screenshot%202024-06-20%20110208.png)

# %% [markdown]
# #### 4- Check the datatypes of each feature.

# %% [markdown]
# ![Screenshot%202024-06-20%20110306.png](attachment:Screenshot%202024-06-20%20110306.png)

# %% [markdown]
# #### 5- Check the Statistical summary

# %% [markdown]
# ![Screenshot%202024-06-20%20110417.png](attachment:Screenshot%202024-06-20%20110417.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20110511.png](attachment:Screenshot%202024-06-20%20110511.png)

# %% [markdown]
# #### check minimum value

# %% [markdown]
# ![Screenshot%202024-06-20%20110626.png](attachment:Screenshot%202024-06-20%20110626.png)

# %% [markdown]
# #### # check maximum value

# %% [markdown]
# ![Screenshot%202024-06-20%20110758.png](attachment:Screenshot%202024-06-20%20110758.png)

# %% [markdown]
# #### # check for percentage wise missing value in columns

# %% [markdown]
# ![Screenshot%202024-06-20%20110842.png](attachment:Screenshot%202024-06-20%20110842.png)

# %% [markdown]
# #### 6- Check the null values

# %% [markdown]
# ![Screenshot%202024-06-20%20110930.png](attachment:Screenshot%202024-06-20%20110930.png)

# %% [markdown]
# #### 7- Check the duplicate values

# %% [markdown]
# ![Screenshot%202024-06-20%20111011.png](attachment:Screenshot%202024-06-20%20111011.png)

# %% [markdown]
# #### # checking the how many total duplicated values present

# %% [markdown]
# ![Screenshot%202024-06-20%20111054.png](attachment:Screenshot%202024-06-20%20111054.png)

# %% [markdown]
# ####  getting rows with  S.F.Ratio as "?"

# %% [markdown]
# ![Screenshot%202024-06-20%20111208.png](attachment:Screenshot%202024-06-20%20111208.png)

# %% [markdown]
# #### Then we use distplot or density plot to check the normality. Normality means whether the data is normally distributed or not

# %% [markdown]
# ![Screenshot%202024-06-20%20111355.png](attachment:Screenshot%202024-06-20%20111355.png)

# %% [markdown]
# #### 9- Check the outliers and their authenticity

# %% [markdown]
# ![Screenshot%202024-06-20%20111521.png](attachment:Screenshot%202024-06-20%20111521.png)

# %% [markdown]
# #### First check for the outliers

# %% [markdown]
# ![Screenshot%202024-06-20%20111659.png](attachment:Screenshot%202024-06-20%20111659.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20111711.png](attachment:Screenshot%202024-06-20%20111711.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20111726.png](attachment:Screenshot%202024-06-20%20111726.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20111736.png](attachment:Screenshot%202024-06-20%20111736.png)

# %% [markdown]
# #### after outliers remove

# %% [markdown]
# ![Screenshot%202024-06-20%20112140.png](attachment:Screenshot%202024-06-20%20112140.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20112225.png](attachment:Screenshot%202024-06-20%20112225.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20112305.png](attachment:Screenshot%202024-06-20%20112305.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20112332.png](attachment:Screenshot%202024-06-20%20112332.png)

# %% [markdown]
# ## 1.Application and Enrollment Analysis

# %% [markdown]
# #### • What is the average number of applications received by colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20014059.png](attachment:Screenshot%202024-06-23%20014059.png)

# %% [markdown]
# ### •	What percentage of applications are accepted on average across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20020142.png](attachment:Screenshot%202024-06-23%20020142.png)

# %% [markdown]
# ### Which college has the highest number of applications received?

# %% [markdown]
# ## 2. Academic Excellence

# %% [markdown]
# ####  •	What is the average percentage of new students from the top 10% of their higher secondary class across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20021151.png](attachment:Screenshot%202024-06-23%20021151.png)

# %% [markdown]
# #### • What is the average percentage of new students from the top 25% of their higher secondary class?

# %% [markdown]
# ![Screenshot%202024-06-23%20021244.png](attachment:Screenshot%202024-06-23%20021244.png)

# %% [markdown]
# ####  Is there a correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class?

# %% [markdown]
# ![Screenshot%202024-06-23%20021812.png](attachment:Screenshot%202024-06-23%20021812.png)

# %% [markdown]
# ## 3. Student Demographics

# %% [markdown]
# #### • What is the average number of full-time undergraduate students per college?

# %% [markdown]
# ![Screenshot%202024-06-23%20022021.png](attachment:Screenshot%202024-06-23%20022021.png)

# %% [markdown]
# #### What is the average number of part-time undergraduate students per college?

# %% [markdown]
# ![Screenshot%202024-06-23%20022151.png](attachment:Screenshot%202024-06-23%20022151.png)

# %% [markdown]
# #### • Which college has the highest number of out-of-state students?

# %% [markdown]
# ![Screenshot%202024-06-23%20022237.png](attachment:Screenshot%202024-06-23%20022237.png)

# %% [markdown]
# ## 4. Cost and Spending

# %% [markdown]
# #### • What is the average cost of room and board across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20022341.png](attachment:Screenshot%202024-06-23%20022341.png)

# %% [markdown]
# #### • What is the average estimated book cost for a student?

# %% [markdown]
# ![Screenshot%202024-06-23%20022627.png](attachment:Screenshot%202024-06-23%20022627.png)

# %% [markdown]
# #### • How does the instructional expenditure per student vary across colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20022736.png](attachment:Screenshot%202024-06-23%20022736.png)

# %% [markdown]
# ![Screenshot%202024-06-23%20022856.png](attachment:Screenshot%202024-06-23%20022856.png)

# %% [markdown]
# ![Screenshot%202024-06-23%20022951.png](attachment:Screenshot%202024-06-23%20022951.png)

# %% [markdown]
# ## 5. Faculty Qualifications

# %% [markdown]
# #### • What is the average percentage of faculties with Ph.D.s across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20023054.png](attachment:Screenshot%202024-06-23%20023054.png)

# %% [markdown]
# #### • What is the average percentage of faculties with terminal degrees?

# %% [markdown]
# ![Screenshot%202024-06-23%20023352.png](attachment:Screenshot%202024-06-23%20023352.png)

# %% [markdown]
# #### .Is there a correlation between the percentage of faculties with Ph.D.s and the graduation rate?

# %% [markdown]
# ![Screenshot%202024-06-23%20023448.png](attachment:Screenshot%202024-06-23%20023448.png)

# %% [markdown]
# ## 6. Student-Faculty Interaction

# %% [markdown]
# #### • What is the average student/faculty ratio across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20024303.png](attachment:Screenshot%202024-06-23%20024303.png)

# %% [markdown]
# #### • Which college has the lowest student/faculty ratio?

# %% [markdown]
# ![Screenshot%202024-06-23%20024525.png](attachment:Screenshot%202024-06-23%20024525.png)

# %% [markdown]
# #### • Is there a correlation between the student/faculty ratio and the graduation rate?

# %% [markdown]
# ![Screenshot%202024-06-23%20024719.png](attachment:Screenshot%202024-06-23%20024719.png)

# %% [markdown]
# ## 7. Alumni Engagement

# %% [markdown]
# #### • What is the average percentage of alumni who donate across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20024822.png](attachment:Screenshot%202024-06-23%20024822.png)

# %% [markdown]
# #### • Is there a correlation between the percentage of alumni who donate and the graduation rate?

# %% [markdown]
# ![Screenshot%202024-06-23%20024922.png](attachment:Screenshot%202024-06-23%20024922.png)

# %% [markdown]
# ## 8. Graduation Rates

# %% [markdown]
# #### • What is the average graduation rate across all colleges?

# %% [markdown]
# ![Screenshot%202024-06-23%20025046.png](attachment:Screenshot%202024-06-23%20025046.png)

# %% [markdown]
# #### •	Which college has the highest graduation rate?

# %% [markdown]
# ![Screenshot%202024-06-23%20025212.png](attachment:Screenshot%202024-06-23%20025212.png)

# %% [markdown]
# #### • Is there a correlation between the instructional expenditure per student and the graduation rate?

# %% [markdown]
# ![Screenshot%202024-06-23%20025317.png](attachment:Screenshot%202024-06-23%20025317.png)
