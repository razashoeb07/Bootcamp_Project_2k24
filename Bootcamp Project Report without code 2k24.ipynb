# %% [markdown]
# ![Screenshot%202024-06-12%20121025.png](attachment:Screenshot%202024-06-12%20121025.png)

# %% [markdown]
# ### Problem Statement/Objetive
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape. By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience. The analysis will provide valuable insights and recommendations for stakeholders in the education sector.

# %% [markdown]
# ### Data Description
# * Names: Names of various university and colleges
# * Apps: Number of applications received
# * Accept: Number of applications accepted
# * Enroll: Number of new students enrolled
# * Top10perc: Percentage of new students from top 10% of Higher Secondary class
# * Top25perc: Percentage of new students from top 25% of Higher Secondary class
# * F.Undergrad: Number of full-time undergraduate students
# * P.Undergrad: Number of part-time undergraduate students
# * Outstate: Number of students for whom the particular college or university is Out-of-state tuition
# * Room.Board: Cost of Room and board
# * Books: Estimated book costs for a student
# * Personal: Estimated personal spending for a student
# * PhD: Percentage of faculties with Ph.D.’s
# * Terminal: Percentage of faculties with terminal degree
# * S.F.Ratio: Student/faculty ratio
# * perc.alumni: Percentage of alumni who donate
# * Expend: The Instructional expenditure per student
# * Grad.Rate: Graduation rate

# %% [markdown]
# #### 1- Display the top 5 rows.

# %% [markdown]
# ![Screenshot%202024-06-20%20105958.png](attachment:Screenshot%202024-06-20%20105958.png)

# %% [markdown]
# #### 2- Display the last 5 rows

# %% [markdown]
# ![Screenshot%202024-06-20%20110112.png](attachment:Screenshot%202024-06-20%20110112.png)

# %% [markdown]
# #### 3- Check the shape of dataset.

# %% [markdown]
# ![Screenshot%202024-06-20%20110208.png](attachment:Screenshot%202024-06-20%20110208.png)

# %% [markdown]
# #### 4- Check the datatypes of each feature.

# %% [markdown]
# ![Screenshot%202024-06-20%20110306.png](attachment:Screenshot%202024-06-20%20110306.png)

# %% [markdown]
# #### 5- Check the Statistical summary

# %% [markdown]
# ![Screenshot%202024-06-20%20110417.png](attachment:Screenshot%202024-06-20%20110417.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20110511.png](attachment:Screenshot%202024-06-20%20110511.png)

# %% [markdown]
# #### check minimum value

# %% [markdown]
# ![Screenshot%202024-06-20%20110626.png](attachment:Screenshot%202024-06-20%20110626.png)

# %% [markdown]
# #### # check maximum value

# %% [markdown]
# ![Screenshot%202024-06-20%20110758.png](attachment:Screenshot%202024-06-20%20110758.png)

# %% [markdown]
# #### # check for percentage wise missing value in columns

# %% [markdown]
# ![Screenshot%202024-06-20%20110842.png](attachment:Screenshot%202024-06-20%20110842.png)

# %% [markdown]
# #### 6- Check the null values

# %% [markdown]
# ![Screenshot%202024-06-20%20110930.png](attachment:Screenshot%202024-06-20%20110930.png)

# %% [markdown]
# #### 7- Check the duplicate values

# %% [markdown]
# ![Screenshot%202024-06-20%20111011.png](attachment:Screenshot%202024-06-20%20111011.png)

# %% [markdown]
# #### # checking the how many total duplicated values present

# %% [markdown]
# ![Screenshot%202024-06-20%20111054.png](attachment:Screenshot%202024-06-20%20111054.png)

# %% [markdown]
# ####  getting rows with  S.F.Ratio as "?"

# %% [markdown]
# ![Screenshot%202024-06-20%20111208.png](attachment:Screenshot%202024-06-20%20111208.png)

# %% [markdown]
# #### Then we use distplot or density plot to check the normality. Normality means whether the data is normally distributed or not

# %% [markdown]
# ![Screenshot%202024-06-20%20111355.png](attachment:Screenshot%202024-06-20%20111355.png)

# %% [markdown]
# #### 9- Check the outliers and their authenticity

# %% [markdown]
# ![Screenshot%202024-06-20%20111521.png](attachment:Screenshot%202024-06-20%20111521.png)

# %% [markdown]
# #### First check for the outliers

# %% [markdown]
# ![Screenshot%202024-06-20%20111659.png](attachment:Screenshot%202024-06-20%20111659.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20111711.png](attachment:Screenshot%202024-06-20%20111711.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20111726.png](attachment:Screenshot%202024-06-20%20111726.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20111736.png](attachment:Screenshot%202024-06-20%20111736.png)

# %% [markdown]
# #### after outliers remove

# %% [markdown]
# ![Screenshot%202024-06-20%20112140.png](attachment:Screenshot%202024-06-20%20112140.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20112225.png](attachment:Screenshot%202024-06-20%20112225.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20112305.png](attachment:Screenshot%202024-06-20%20112305.png)

# %% [markdown]
# ![Screenshot%202024-06-20%20112332.png](attachment:Screenshot%202024-06-20%20112332.png)
